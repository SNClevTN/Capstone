# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd

# %%
import tabula

# %%
tabula.read_pdf('../data/2020_IC3Report-16.pdf', pages='all')
# Out:
#    Unnamed: 0    Victims  Unnamed: 2  Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0         NaN  ge Range7         NaN         NaN  Total Count         NaN
#
#    Unnamed: 6 Unnamed: 7  Unnamed: 8
# 0         NaN  Total Los         NaN

# %%
import PyPDF2

# %%
pdfFileObj = open('../data/2020_IC3Report-16.pdf', 'rb')

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
pageObj = pdfReader.getPage(0)

# %%
text=pageObj.extractText()
print(text)
# Out:
#
# 16
#
#
# 20
# 20
#
# VICTIMS BY
# AGE GROUP
#
# Victims
#
# Age
#
# Range
# 7
#
# Total Count
#
# Total Loss
#
# Under 20
#
# 23,186
#
# $
# 70,980,763
#
# 20
# -
#
# 29
#
# 70,791
#
# $
# 197,402,240
#
# 30
# -
#
# 39
#
# 88,364
#
# $
# 492,176,845
#
# 40
# -
#
# 49
#
# 91,568
#
# $
# 717,161,726
#
# 50
# -
#
# 59
#
# 85,967
#
# $
# 847,948,101
#
# Over 60
#
# 105,301
#
# $
# 966,062,236
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7
#
# Not all complaints include an associated age range
#
# those without this information are excluded f
# rom this
# table. Please see Appendix B for more information regarding IC3 data.

# %%
text.split('\n')
# Out:
# [' ',
#  '16',
#  ' ',
#  '   ',
#  '20',
#  '20',
#  ' ',
#  'VICTIMS BY ',
#  'AGE GROUP',
#  ' ',
#  'Victims',
#  ' ',
#  'Age',
#  ' ',
#  'Range',
#  '7',
#  ' ',
#  'Total Count',
#  ' ',
#  'Total Loss',
#  ' ',
#  'Under 20',
#  ' ',
#  '23,186',
#  ' ',
#  '$',
#  '70,980,763',
#  ' ',
#  '20 ',
#  '-',
#  ' ',
#  '29',
#  ' ',
#  '70,791',
#  ' ',
#  '$',
#  '197,402,240',
#  ' ',
#  '30 ',
#  '-',
#  ' ',
#  '39',
#  ' ',
#  '88,364',
#  ' ',
#  '$',
#  '492,176,845',
#  ' ',
#  '40 ',
#  '-',
#  ' ',
#  '49',
#  ' ',
#  '91,568',
#  ' ',
#  '$',
#  '717,161,726',
#  ' ',
#  '50 ',
#  '-',
#  ' ',
#  '59',
#  ' ',
#  '85,967',
#  ' ',
#  '$',
#  '847,948,101',
#  ' ',
#  'Over 60',
#  ' ',
#  '105,301',
#  ' ',
#  '$',
#  '966,062,236',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '7',
#  ' ',
#  'Not all complaints include an associated age range',
#  '',
#  'those without this information are excluded f',
#  'rom this ',
#  'table. Please see Appendix B for more information regarding IC3 data. ',
#  ' ',
#  ' ',
#  '']
